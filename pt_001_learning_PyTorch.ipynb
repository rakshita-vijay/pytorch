# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshita-vijay/pytorch/blob/main/pt_001_learning_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -------------------------------
# absl-py                   1.4.0
# accelerate                1.8.1
# aiohappyeyeballs          2.6.1
# aiohttp                   3.11.15
# aiosignal                 1.3.2
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.9.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# array_record              0.7.2
# attrs                     25.3.0
# audioread                 3.0.1
# backcall                  0.2.0
# beautifulsoup4            4.13.4
# betterproto               2.0.0b6
# bleach                    6.2.0
# blinker                   1.4
# blis                      1.3.0
# cachetools                5.5.2
# catalogue                 2.0.10
# certifi                   2025.6.15
# cffi                      1.17.1
# charset-normalizer        3.4.2
# chex                      0.1.89
# click                     8.2.1
# ...
